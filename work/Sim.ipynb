# %%
import numpy as np

# %%
from importlib import reload

# %%
import results

# %%
import functions

# %%
results.CM / results.const["AU"]
# Out:
# array([0.00922801, 0.        , 0.        ])

# %%
results.mj
# Out:
# array([1.990000e+30, 5.972170e+24, 4.867310e+24, 3.301030e+23,
#        6.416910e+23, 1.898125e+27, 5.683170e+26, 1.024092e+26])

# %%
M = np.sum(results.mj)

# %%
M
# Out:
# 1.9925806624739998e+30
